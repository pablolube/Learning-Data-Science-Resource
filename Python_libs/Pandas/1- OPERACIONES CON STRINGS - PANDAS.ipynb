# %% [markdown]
# #LINKS DE INTERES

# %% [markdown]
# **MATERIAL COMPLEMENTARIO PYTHON**

# %% [markdown]
# En los iguientes recursos pueden encontrar lo que vimos esta semana con ejemplos, explicaciones y a más profundidad.
#
# PYTHON ESTRUCTURAS
#   Videos de Educación en YouTube
#   Estructura FOR acompañado de range: video
#   Estructura FOR en general: video
#   Estructura While basica: video
#   Estructura IF: video
# FUNCIONES
#   Funciones: video
# FOROS
#   Foros: Pueden buscar en español o en inglés sus preguntas.
#   STACKOVERFLOW: Ejemplo de una pregunta en este foro para que lo empiecen a usar
#   Quora: Ejemplo
#
# PAGINAS CON TUTORIALES
#   Páginas con muchos tutoriales
#
#
# https://ellibrodepython.com/
#
# https://www.freecodecamp.org/espanol/news/tag/python/
#
# Documentación oficial de Python para aquell@s que quieren profundizar en las estructuras de manera teórica
#
# https://docs.python.org/es/3/tutorial/
#
# ¿Qué pasa si me gusta leer libros para aprender?
#
# Podemos encontrar en internet pdf gratuitos de libros como este

# %% [markdown]
# Manual, hoja de trucos (cheat sheet) o resumen con varios comandos de código importantes de Pandas y NumPy
#
# Pandas:
#
# https://aprendeconalf.es/docencia/python/manual/pandas/
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
# Numpy:
#
# https://www.freecodecamp.org/espanol/news/la-guia-definitiva-del-paquete-numpy-para-computacion-cientifica-en-python/
# https://www.datacamp.com/cheat-sheet/numpy-cheat-sheet-data-analysis-in-python
# Páginas similares a HackerRank para practicar Ciencia de Datos con retos y ejercicios
#
# https://www.kaggle.com/learn
# https://www.datacamp.com/
# https://www.codecademy.com/
# -- Para practicar Python de manera gratuita (agrego página de Hackerank para personas que no la conozcan):
#
# https://www.hackerrank.com/domains/python
# https://exercism.org/tracks/python
# Tutoriales adicionales para entender más el .groupby() de pandas
#
# https://www.youtube.com/watch?v=xaM-YolPFB0
# https://interactivechaos.com/es/manual/tutorial-de-pandas/agrupaciones-en-dataframes
# https://sparkbyexamples.com/pandas/pandas-groupby-explained-with-examples/
# Tutorial de cómo exportar o descargar diferentes tipos de archivos usando Python
#
# Para exportar csv o archivos de excel: https://gonzalezgouveia.com/como-exportar-data-frames-de-pandas-a-csv-o-excel-en-python/
# Para exportar archivo de texto: https://www.adamsmith.haus/python/answers/how-to-write-contents-of-a-dataframe-into-a-text-file-in-python

# %% [markdown]
# # PANDAS 2

# %%
import pandas as pd
import numpy as np

from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-c363abc5b340> in <cell line: 6>()
#       4 from google.colab import drive
#       5 import os
# ----> 6 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
#     278     elif case == 4:
#     279       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %% [markdown]
# ## OPERACIONES CON STRINGS

# %%
Presidentes_archivo = pd.read_csv("/content/gdrive/MyDrive/0) DATA SCIENCE/3-Pandas/us_presidents 2.csv") #dataset presidentes de USA

Presidentes_archivo.tail(10) #opuesto de dataframe.head(), nos permite ver ultimas 10 filas del dataframe
# Out:
#     Unnamed: 0  S.No.              start               end          president  \
# 35          35     36  November 22, 1963  January 20, 1969  Lyndon B. Johnson
# 36          36     37   January 20, 1969    August 9, 1974      Richard Nixon
# 37          37     38     August 9, 1974  January 20, 1977        Gerald Ford
# 38          38     39   January 20, 1977  January 20, 1981       Jimmy Carter
# 39          39     40   January 20, 1981  January 20, 1989      Ronald Reagan
# 40          40     41   January 20, 1989  January 20, 1993  George H. W. Bush
# 41          41     42   January 20, 1993  January 20, 2001       Bill Clinton
# 42          42     43   January 20, 2001  January 20, 2009     George W. Bush
# 43          43     44   January 20, 2009               NaN       Barack Obama
# 44          44     45   January 20, 2017                --       Donald Trump
#
#                                                 prior       party  \
# 35          37th  Vice President of the United States  Democratic
# 36  36th  Vice President of the United States   (1...  Republican
# 37          40th  Vice President of the United States  Republican
# 38            76th  Governor of Georgia   (1971–1975)  Democratic
# 39       33rd  Governor of California   ( 1967–1975 )  Republican
# 40          43rd  Vice President of the United States  Republican
# 41  40th & 42nd  Governor of Arkansas   (1979–1981...  Democratic
# 42            46th  Governor of Texas   ( 1995–2000 )  Republican
# 43  U.S. Senator   ( Class 3 )   from  Illinois   ...  Democratic
# 44  Chairman of   The Trump Organization   ( 1971–...  Republican
#
#                  vice
# 35      Office vacant
# 36        Spiro Agnew
# 37      Office vacant
# 38     Walter Mondale
# 39  George H. W. Bush
# 40         Dan Quayle
# 41            Al Gore
# 42        Dick Cheney
# 43          Joe Biden
# 44         Mike Pence

# %%
Presidentes_nombres =Presidentes_archivo['president']
Presidentes_nombres
# Out:
# 0          George Washington
# 1                 John Adams
# 2           Thomas Jefferson
# 3              James Madison
# 4               James Monroe
# 5          John Quincy Adams
# 6             Andrew Jackson
# 7           Martin Van Buren
# 8     William Henry Harrison
# 9                 John Tyler
# 10             James K. Polk
# 11            Zachary Taylor
# 12          Millard Fillmore
# 13           Franklin Pierce
# 14            James Buchanan
# 15           Abraham Lincoln
# 16            Andrew Johnson
# 17          Ulysses S. Grant
# 18       Rutherford B. Hayes
# 19         James A. Garfield
# 20         Chester A. Arthur
# 21          Grover Cleveland
# 22         Benjamin Harrison
# 23          Grover Cleveland
# 24          William McKinley
# 25        Theodore Roosevelt
# 26       William Howard Taft
# 27            Woodrow Wilson
# 28         Warren G. Harding
# 29           Calvin Coolidge
# 30            Herbert Hoover
# 31     Franklin D. Roosevelt
# 32           Harry S. Truman
# 33      Dwight D. Eisenhower
# 34           John F. Kennedy
# 35         Lyndon B. Johnson
# 36             Richard Nixon
# 37               Gerald Ford
# 38              Jimmy Carter
# 39             Ronald Reagan
# 40         George H. W. Bush
# 41              Bill Clinton
# 42            George W. Bush
# 43              Barack Obama
# 44              Donald Trump
# Name: president, dtype: object

# %%
Presidentes_archivo.tail(10) #opuesto de dataframe.head(), nos permite ver ultimas 10 filas del dataframe
# Out:
#     Unnamed: 0  S.No.              start               end          president  \
# 35          35     36  November 22, 1963  January 20, 1969  Lyndon B. Johnson
# 36          36     37   January 20, 1969    August 9, 1974      Richard Nixon
# 37          37     38     August 9, 1974  January 20, 1977        Gerald Ford
# 38          38     39   January 20, 1977  January 20, 1981       Jimmy Carter
# 39          39     40   January 20, 1981  January 20, 1989      Ronald Reagan
# 40          40     41   January 20, 1989  January 20, 1993  George H. W. Bush
# 41          41     42   January 20, 1993  January 20, 2001       Bill Clinton
# 42          42     43   January 20, 2001  January 20, 2009     George W. Bush
# 43          43     44   January 20, 2009               NaN       Barack Obama
# 44          44     45   January 20, 2017                --       Donald Trump
#
#                                                 prior       party  \
# 35          37th  Vice President of the United States  Democratic
# 36  36th  Vice President of the United States   (1...  Republican
# 37          40th  Vice President of the United States  Republican
# 38            76th  Governor of Georgia   (1971–1975)  Democratic
# 39       33rd  Governor of California   ( 1967–1975 )  Republican
# 40          43rd  Vice President of the United States  Republican
# 41  40th & 42nd  Governor of Arkansas   (1979–1981...  Democratic
# 42            46th  Governor of Texas   ( 1995–2000 )  Republican
# 43  U.S. Senator   ( Class 3 )   from  Illinois   ...  Democratic
# 44  Chairman of   The Trump Organization   ( 1971–...  Republican
#
#                  vice
# 35      Office vacant
# 36        Spiro Agnew
# 37      Office vacant
# 38     Walter Mondale
# 39  George H. W. Bush
# 40         Dan Quayle
# 41            Al Gore
# 42        Dick Cheney
# 43          Joe Biden
# 44         Mike Pence

# %%
# tomamos solo la columna con los nombres de los presidentes para los ejemplos
Presidentes_nombres =Presidentes_archivo['president']

Presidentes_nombres.head(5) #visualizo aca los 5 primeros nombres
# Out:
# 0    George Washington
# 1           John Adams
# 2     Thomas Jefferson
# 3        James Madison
# 4         James Monroe
# Name: president, dtype: object

# %% [markdown]
# #### UPPER

# %%
#STR.como cambiar los nombres a MAYUSCULAS

Presidentes_nombres.str.upper()
#Presidentes_nombres.str.upper().head(5) #para los 5 primeros nombres
# Out:
# 0          GEORGE WASHINGTON
# 1                 JOHN ADAMS
# 2           THOMAS JEFFERSON
# 3              JAMES MADISON
# 4               JAMES MONROE
# 5          JOHN QUINCY ADAMS
# 6             ANDREW JACKSON
# 7           MARTIN VAN BUREN
# 8     WILLIAM HENRY HARRISON
# 9                 JOHN TYLER
# 10             JAMES K. POLK
# 11            ZACHARY TAYLOR
# 12          MILLARD FILLMORE
# 13           FRANKLIN PIERCE
# 14            JAMES BUCHANAN
# 15           ABRAHAM LINCOLN
# 16            ANDREW JOHNSON
# 17          ULYSSES S. GRANT
# 18       RUTHERFORD B. HAYES
# 19         JAMES A. GARFIELD
# 20         CHESTER A. ARTHUR
# 21          GROVER CLEVELAND
# 22         BENJAMIN HARRISON
# 23          GROVER CLEVELAND
# 24          WILLIAM MCKINLEY
# 25        THEODORE ROOSEVELT
# 26       WILLIAM HOWARD TAFT
# 27            WOODROW WILSON
# 28         WARREN G. HARDING
# 29           CALVIN COOLIDGE
# 30            HERBERT HOOVER
# 31     FRANKLIN D. ROOSEVELT
# 32           HARRY S. TRUMAN
# 33      DWIGHT D. EISENHOWER
# 34           JOHN F. KENNEDY
# 35         LYNDON B. JOHNSON
# 36             RICHARD NIXON
# 37               GERALD FORD
# 38              JIMMY CARTER
# 39             RONALD REAGAN
# 40         GEORGE H. W. BUSH
# 41              BILL CLINTON
# 42            GEORGE W. BUSH
# 43              BARACK OBAMA
# 44              DONALD TRUMP
# Name: president, dtype: object

# %% [markdown]
# ###LOWER

# %%
Presidentes_nombres.str.lower()
# Out:
# 0          george washington
# 1                 john adams
# 2           thomas jefferson
# 3              james madison
# 4               james monroe
# 5          john quincy adams
# 6             andrew jackson
# 7           martin van buren
# 8     william henry harrison
# 9                 john tyler
# 10             james k. polk
# 11            zachary taylor
# 12          millard fillmore
# 13           franklin pierce
# 14            james buchanan
# 15           abraham lincoln
# 16            andrew johnson
# 17          ulysses s. grant
# 18       rutherford b. hayes
# 19         james a. garfield
# 20         chester a. arthur
# 21          grover cleveland
# 22         benjamin harrison
# 23          grover cleveland
# 24          william mckinley
# 25        theodore roosevelt
# 26       william howard taft
# 27            woodrow wilson
# 28         warren g. harding
# 29           calvin coolidge
# 30            herbert hoover
# 31     franklin d. roosevelt
# 32           harry s. truman
# 33      dwight d. eisenhower
# 34           john f. kennedy
# 35         lyndon b. johnson
# 36             richard nixon
# 37               gerald ford
# 38              jimmy carter
# 39             ronald reagan
# 40         george h. w. bush
# 41              bill clinton
# 42            george w. bush
# 43              barack obama
# 44              donald trump
# Name: president, dtype: object

# %% [markdown]
# ### LEN

# %%
#Cuento el largo del dato

Presidentes_nombres.str.len()
#Presidentes_nombres.str.upper().head(5) #para los 5 primeros nombres
# Out:
# 0     17
# 1     10
# 2     16
# 3     13
# 4     12
# 5     17
# 6     14
# 7     16
# 8     22
# 9     10
# 10    13
# 11    14
# 12    16
# 13    15
# 14    14
# 15    15
# 16    14
# 17    16
# 18    19
# 19    17
# 20    17
# 21    16
# 22    17
# 23    16
# 24    16
# 25    18
# 26    19
# 27    14
# 28    17
# 29    15
# 30    14
# 31    21
# 32    15
# 33    20
# 34    15
# 35    17
# 36    13
# 37    11
# 38    12
# 39    13
# 40    17
# 41    12
# 42    14
# 43    12
# 44    12
# Name: president, dtype: int64

# %% [markdown]
# ### START WITH

# %%
#Empiezan con j
Presidentes_nombres.str.startswith("j")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# Name: president, dtype: bool

# %% [markdown]
# ### SPLIT

# %%
#para convertir cada formato a tipo lista, separando despues de cada espacio con comas

Presidentes_nombres.str.split()
# Out:
# 0           [George, Washington]
# 1                  [John, Adams]
# 2            [Thomas, Jefferson]
# 3               [James, Madison]
# 4                [James, Monroe]
# 5          [John, Quincy, Adams]
# 6              [Andrew, Jackson]
# 7           [Martin, Van, Buren]
# 8     [William, Henry, Harrison]
# 9                  [John, Tyler]
# 10             [James, K., Polk]
# 11             [Zachary, Taylor]
# 12           [Millard, Fillmore]
# 13            [Franklin, Pierce]
# 14             [James, Buchanan]
# 15            [Abraham, Lincoln]
# 16             [Andrew, Johnson]
# 17          [Ulysses, S., Grant]
# 18       [Rutherford, B., Hayes]
# 19         [James, A., Garfield]
# 20         [Chester, A., Arthur]
# 21           [Grover, Cleveland]
# 22          [Benjamin, Harrison]
# 23           [Grover, Cleveland]
# 24           [William, McKinley]
# 25         [Theodore, Roosevelt]
# 26       [William, Howard, Taft]
# 27             [Woodrow, Wilson]
# 28         [Warren, G., Harding]
# 29            [Calvin, Coolidge]
# 30             [Herbert, Hoover]
# 31     [Franklin, D., Roosevelt]
# 32           [Harry, S., Truman]
# 33      [Dwight, D., Eisenhower]
# 34           [John, F., Kennedy]
# 35         [Lyndon, B., Johnson]
# 36              [Richard, Nixon]
# 37                [Gerald, Ford]
# 38               [Jimmy, Carter]
# 39              [Ronald, Reagan]
# 40        [George, H., W., Bush]
# 41               [Bill, Clinton]
# 42            [George, W., Bush]
# 43               [Barack, Obama]
# 44               [Donald, Trump]
# Name: president, dtype: object

# %% [markdown]
# ### REGEX

# %%
import re
Presidentes_nombres[~Presidentes_nombres.str.contains(pat='Bill|Calvin', regex=True)]# si se pone True, se asume que es una regular expression
# Out:
# 0          George Washington
# 1                 John Adams
# 2           Thomas Jefferson
# 3              James Madison
# 4               James Monroe
# 5          John Quincy Adams
# 6             Andrew Jackson
# 7           Martin Van Buren
# 8     William Henry Harrison
# 9                 John Tyler
# 10             James K. Polk
# 11            Zachary Taylor
# 12          Millard Fillmore
# 13           Franklin Pierce
# 14            James Buchanan
# 15           Abraham Lincoln
# 16            Andrew Johnson
# 17          Ulysses S. Grant
# 18       Rutherford B. Hayes
# 19         James A. Garfield
# 20         Chester A. Arthur
# 21          Grover Cleveland
# 22         Benjamin Harrison
# 23          Grover Cleveland
# 24          William McKinley
# 25        Theodore Roosevelt
# 26       William Howard Taft
# 27            Woodrow Wilson
# 28         Warren G. Harding
# 30            Herbert Hoover
# 31     Franklin D. Roosevelt
# 32           Harry S. Truman
# 33      Dwight D. Eisenhower
# 34           John F. Kennedy
# 35         Lyndon B. Johnson
# 36             Richard Nixon
# 37               Gerald Ford
# 38              Jimmy Carter
# 39             Ronald Reagan
# 40         George H. W. Bush
# 42            George W. Bush
# 43              Barack Obama
# 44              Donald Trump
# Name: president, dtype: object

# %%
Presidentes_nombres.str.replace(pat='Calvin',repl=' ',)
# Out:
# 0          George Washington
# 1                 John Adams
# 2           Thomas Jefferson
# 3              James Madison
# 4               James Monroe
# 5          John Quincy Adams
# 6             Andrew Jackson
# 7           Martin Van Buren
# 8     William Henry Harrison
# 9                 John Tyler
# 10             James K. Polk
# 11            Zachary Taylor
# 12          Millard Fillmore
# 13           Franklin Pierce
# 14            James Buchanan
# 15           Abraham Lincoln
# 16            Andrew Johnson
# 17          Ulysses S. Grant
# 18       Rutherford B. Hayes
# 19         James A. Garfield
# 20         Chester A. Arthur
# 21          Grover Cleveland
# 22         Benjamin Harrison
# 23          Grover Cleveland
# 24          William McKinley
# 25        Theodore Roosevelt
# 26       William Howard Taft
# 27            Woodrow Wilson
# 28         Warren G. Harding
# 29                  Coolidge
# 30            Herbert Hoover
# 31     Franklin D. Roosevelt
# 32           Harry S. Truman
# 33      Dwight D. Eisenhower
# 34           John F. Kennedy
# 35         Lyndon B. Johnson
# 36             Richard Nixon
# 37               Gerald Ford
# 38              Jimmy Carter
# 39             Ronald Reagan
# 40         George H. W. Bush
# 41              Bill Clinton
# 42            George W. Bush
# 43              Barack Obama
# 44              Donald Trump
# Name: president, dtype: object
